# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/MMRA')

# %%
import MMRA.test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2302312892.py in <cell line: 0>()
# ----> 1 import MMRA.test
#
# /content/gdrive/MyDrive/MMRA/MMRA/test.py in <module>
#       8 from tqdm import tqdm
#       9 from sklearn.metrics import mean_absolute_error
# ---> 10 from dataloader.MicroLens100k.dataset import MyData, custom_collate_fn
#      11 import random
#      12 import numpy as np
#
# ModuleNotFoundError: No module named 'dataloader'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
! pwd
# Out:
# /content/gdrive/MyDrive/MMRA
